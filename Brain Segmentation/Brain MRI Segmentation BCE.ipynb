# %% [markdown]
# ### Brain MRI segmentation with Unet

# %% [markdown]
# The data were taken from https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation

# %% [markdown]
# #### Import the libraries

# %%
import os
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ### Import the data

# %%
DataPath = "lgg-mri-segmentation/kaggle_3m/"

dirs = []
images = []
masks = []
for dirname, _, filenames in os.walk(DataPath):
    for filename in filenames:
        if 'mask'in filename:
            dirs.append(dirname.replace(DataPath, ''))
            masks.append(filename)
            images.append(filename.replace('_mask', ''))
            
            
imagePath_df = pd.DataFrame({'directory':dirs, 'images': images, 'masks': masks})

# %%
imagePath_df.head()
# Out:
#                directory                        images  \
# 0  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_10.tif
# 1  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_11.tif
# 2  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_12.tif
# 3  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_13.tif
# 4  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_14.tif
#
#                                masks
# 0  TCGA_CS_4941_19960909_10_mask.tif
# 1  TCGA_CS_4941_19960909_11_mask.tif
# 2  TCGA_CS_4941_19960909_12_mask.tif
# 3  TCGA_CS_4941_19960909_13_mask.tif
# 4  TCGA_CS_4941_19960909_14_mask.tif

# %%
imagePath_df.shape
# Out:
# (3929, 3)

# %%
# Check the size of the image 

def print_imShape():
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    print(image.shape, mask.shape)
    
    
for i in range(3):
    print_imShape()
# Out:
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)

# %% [markdown]
# ### Visualize the data

# %%
def plot_images():
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    fig, axs = plt.subplots(1,3, figsize=[15,15])
    
    axs[0].imshow(image)
    axs[0].set_title('MRI')
    
    axs[1].imshow(mask)
    axs[1].set_title('Mask')
    
    axs[2].imshow(image)
    axs[2].imshow(mask, alpha=0.3)
    axs[2].set_title('MRI with mask')
    
    plt.grid(False)
    plt.show()
    
    
for i in range(3):
    plot_images()

# %%
imagePath_df['image-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['images']
imagePath_df['mask-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['masks']

# %%
# Finaldataframe with image and mask directories 
imagePath_df.head(2)
# Out:
#                directory                        images  \
# 0  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_10.tif
# 1  TCGA_CS_4941_19960909  TCGA_CS_4941_19960909_11.tif
#
#                                masks  \
# 0  TCGA_CS_4941_19960909_10_mask.tif
# 1  TCGA_CS_4941_19960909_11_mask.tif
#
#                                           image-path  \
# 0  lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19...
# 1  lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19...
#
#                                            mask-path
# 0  lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19...
# 1  lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19...

# %% [markdown]
# ### Data Generator

# %% [markdown]
# ##### Train Data

# %%
train1 , test = train_test_split(imagePath_df, test_size=0.10)

train , val = train_test_split(train1, test_size=0.10)




EPOCHS = 100
BATCH_SIZE = 32
ImgHeight = 256
ImgWidth = 256
Channels = 3


# Data Augmentation 

data_augmentation = dict(rotation_range=0.2,
                        width_shift_range=0.05,
                        height_shift_range=0.05,
                        shear_range=0.05,
                        zoom_range=0.05,
                        horizontal_flip=True,
                        fill_mode='nearest')




# image and mask generator
imagegen = ImageDataGenerator(rescale=1./255., **data_augmentation)
maskgen = ImageDataGenerator(rescale=1./255., **data_augmentation)


# train generator
timage_generator=imagegen.flow_from_dataframe(dataframe=train,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='rgb')
# validation data generator
tmask_generator=maskgen.flow_from_dataframe(dataframe=train,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 3182 validated image filenames.
# Found 3182 validated image filenames.

# %% [markdown]
# ###### Validation Data

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255.)
maskgen = ImageDataGenerator(rescale=1./255.)


# train generator
vimage_generator=imagegen.flow_from_dataframe(dataframe=val,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='rgb')
# validation data generator
vmask_generator=maskgen.flow_from_dataframe(dataframe=val,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 354 validated image filenames.
# Found 354 validated image filenames.

# %% [markdown]
# #### Test Data

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255.)
maskgen = ImageDataGenerator(rescale=1./255.)


# train generator
teimage_generator=imagegen.flow_from_dataframe(dataframe=test,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='rgb')
# validation data generator
temask_generator=maskgen.flow_from_dataframe(dataframe=test,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHeight,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.

# %%
# Create a  function for generating the images and masks 
def data_gen(image_gen, mask_gen):
    for img, mask in zip(image_gen, mask_gen):
        yield img, mask

# %%
train_gen = data_gen(timage_generator, tmask_generator)
valid_gen = data_gen(vimage_generator, vmask_generator)
test_gen = data_gen(teimage_generator, temask_generator)

# %% [markdown]
# ### Dice loss Function

# %%
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + 100) / (K.sum(y_truef) + K.sum(y_predf) + 100))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# ##### Create Unet

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    
    # Encoding 
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Decoding 
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
# Compile the model

input_img = Input((ImgHeight, ImgWidth, 3), name='img')
model = unet(input_img, n_filters=16, dropout=0.2, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy", dice_coef, dice_coef_loss])

# %%
# Model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 16) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 4624        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 32) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  17          activation_17[0][0]
# ==================================================================================================
# Total params: 1,179,409
# Trainable params: 1,177,937
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# Callbacks 

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-5, verbose=1),
    ModelCheckpoint('model-brain-mri_bce.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
STEP_SIZE_TRAIN = timage_generator.n/BATCH_SIZE
STEP_SIZE_VALID = vimage_generator.n/BATCH_SIZE
STEP_SIZE_TEST = teimage_generator.n/BATCH_SIZE

# %%
results = model.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=STEP_SIZE_VALID)
# Out:
# Epoch 1/100
# 99/99 [==============================] - 62s 507ms/step - loss: 0.2962 - accuracy: 0.9566 - dice_coef: 0.0290 - dice_coef_loss: 0.9710 - val_loss: 0.2118 - val_accuracy: 0.9856 - val_dice_coef: 0.0251 - val_dice_coef_loss: 0.9749
#
# Epoch 00001: val_loss improved from inf to 0.21185, saving model to model-brain-mri_bce.h5
# Epoch 2/100
# 99/99 [==============================] - 55s 557ms/step - loss: 0.1197 - accuracy: 0.9892 - dice_coef: 0.0523 - dice_coef_loss: 0.9477 - val_loss: 0.1020 - val_accuracy: 0.9908 - val_dice_coef: 0.0578 - val_dice_coef_loss: 0.9422
#
# Epoch 00002: val_loss improved from 0.21185 to 0.10198, saving model to model-brain-mri_bce.h5
# Epoch 3/100
# 99/99 [==============================] - 49s 494ms/step - loss: 0.0851 - accuracy: 0.9891 - dice_coef: 0.0223 - dice_coef_loss: 0.9777 - val_loss: 0.0702 - val_accuracy: 0.9906 - val_dice_coef: 0.0241 - val_dice_coef_loss: 0.9759
#
# Epoch 00003: val_loss improved from 0.10198 to 0.07024, saving model to model-brain-mri_bce.h5
# Epoch 4/100
# 99/99 [==============================] - 47s 473ms/step - loss: 0.0550 - accuracy: 0.9900 - dice_coef: 0.1154 - dice_coef_loss: 0.8846 - val_loss: 0.0603 - val_accuracy: 0.9915 - val_dice_coef: 0.1367 - val_dice_coef_loss: 0.8633
#
# Epoch 00004: val_loss improved from 0.07024 to 0.06025, saving model to model-brain-mri_bce.h5
# Epoch 5/100
# 99/99 [==============================] - 47s 474ms/step - loss: 0.0602 - accuracy: 0.9890 - dice_coef: 0.0240 - dice_coef_loss: 0.9760 - val_loss: 0.0494 - val_accuracy: 0.9904 - val_dice_coef: 0.0430 - val_dice_coef_loss: 0.9570
#
# Epoch 00005: val_loss improved from 0.06025 to 0.04938, saving model to model-brain-mri_bce.h5
# Epoch 6/100
# 99/99 [==============================] - 48s 487ms/step - loss: 0.0368 - accuracy: 0.9918 - dice_coef: 0.2197 - dice_coef_loss: 0.7803 - val_loss: 0.0337 - val_accuracy: 0.9934 - val_dice_coef: 0.2440 - val_dice_coef_loss: 0.7560
#
# Epoch 00006: val_loss improved from 0.04938 to 0.03365, saving model to model-brain-mri_bce.h5
# Epoch 7/100
# 99/99 [==============================] - 49s 495ms/step - loss: 0.0290 - accuracy: 0.9932 - dice_coef: 0.3278 - dice_coef_loss: 0.6722 - val_loss: 0.0256 - val_accuracy: 0.9944 - val_dice_coef: 0.2689 - val_dice_coef_loss: 0.7311
#
# Epoch 00007: val_loss improved from 0.03365 to 0.02558, saving model to model-brain-mri_bce.h5
# Epoch 8/100
# 99/99 [==============================] - 51s 514ms/step - loss: 0.0247 - accuracy: 0.9935 - dice_coef: 0.3896 - dice_coef_loss: 0.6104 - val_loss: 0.0234 - val_accuracy: 0.9942 - val_dice_coef: 0.4324 - val_dice_coef_loss: 0.5676
#
# Epoch 00008: val_loss improved from 0.02558 to 0.02337, saving model to model-brain-mri_bce.h5
# Epoch 9/100
# 99/99 [==============================] - 49s 498ms/step - loss: 0.0214 - accuracy: 0.9940 - dice_coef: 0.4437 - dice_coef_loss: 0.5563 - val_loss: 0.0177 - val_accuracy: 0.9952 - val_dice_coef: 0.5306 - val_dice_coef_loss: 0.4694
#
# Epoch 00009: val_loss improved from 0.02337 to 0.01773, saving model to model-brain-mri_bce.h5
# Epoch 10/100
# 99/99 [==============================] - 47s 474ms/step - loss: 0.0198 - accuracy: 0.9941 - dice_coef: 0.4723 - dice_coef_loss: 0.5277 - val_loss: 0.0165 - val_accuracy: 0.9953 - val_dice_coef: 0.5322 - val_dice_coef_loss: 0.4678
#
# Epoch 00010: val_loss improved from 0.01773 to 0.01650, saving model to model-brain-mri_bce.h5
# Epoch 11/100
# 99/99 [==============================] - 45s 459ms/step - loss: 0.0179 - accuracy: 0.9944 - dice_coef: 0.5126 - dice_coef_loss: 0.4874 - val_loss: 0.0145 - val_accuracy: 0.9958 - val_dice_coef: 0.5295 - val_dice_coef_loss: 0.4705
#
# Epoch 00011: val_loss improved from 0.01650 to 0.01446, saving model to model-brain-mri_bce.h5
# Epoch 12/100
# 99/99 [==============================] - 46s 462ms/step - loss: 0.0164 - accuracy: 0.9946 - dice_coef: 0.5409 - dice_coef_loss: 0.4591 - val_loss: 0.0169 - val_accuracy: 0.9956 - val_dice_coef: 0.5162 - val_dice_coef_loss: 0.4838
#
# Epoch 00012: val_loss did not improve from 0.01446
# Epoch 13/100
# 99/99 [==============================] - 45s 458ms/step - loss: 0.0516 - accuracy: 0.9889 - dice_coef: 0.0265 - dice_coef_loss: 0.9735 - val_loss: 0.0451 - val_accuracy: 0.9904 - val_dice_coef: 0.0458 - val_dice_coef_loss: 0.9542
#
# Epoch 00013: val_loss did not improve from 0.01446
# Epoch 14/100
# 99/99 [==============================] - 45s 460ms/step - loss: 0.0228 - accuracy: 0.9929 - dice_coef: 0.4082 - dice_coef_loss: 0.5918 - val_loss: 0.0167 - val_accuracy: 0.9952 - val_dice_coef: 0.5455 - val_dice_coef_loss: 0.4545
#
# Epoch 00014: val_loss did not improve from 0.01446
# Epoch 15/100
# 99/99 [==============================] - 46s 463ms/step - loss: 0.0160 - accuracy: 0.9945 - dice_coef: 0.5622 - dice_coef_loss: 0.4378 - val_loss: 0.0154 - val_accuracy: 0.9954 - val_dice_coef: 0.5352 - val_dice_coef_loss: 0.4648
#
# Epoch 00015: val_loss did not improve from 0.01446
# Epoch 16/100
# 99/99 [==============================] - 47s 471ms/step - loss: 0.0148 - accuracy: 0.9947 - dice_coef: 0.5837 - dice_coef_loss: 0.4163 - val_loss: 0.0133 - val_accuracy: 0.9956 - val_dice_coef: 0.5869 - val_dice_coef_loss: 0.4131
#
# Epoch 00016: val_loss improved from 0.01446 to 0.01326, saving model to model-brain-mri_bce.h5
# Epoch 17/100
# 99/99 [==============================] - 45s 460ms/step - loss: 0.0139 - accuracy: 0.9949 - dice_coef: 0.6102 - dice_coef_loss: 0.3898 - val_loss: 0.0112 - val_accuracy: 0.9964 - val_dice_coef: 0.6469 - val_dice_coef_loss: 0.3531
#
# Epoch 00017: val_loss improved from 0.01326 to 0.01123, saving model to model-brain-mri_bce.h5
# Epoch 18/100
# 99/99 [==============================] - 46s 461ms/step - loss: 0.0127 - accuracy: 0.9952 - dice_coef: 0.6355 - dice_coef_loss: 0.3645 - val_loss: 0.0109 - val_accuracy: 0.9965 - val_dice_coef: 0.6025 - val_dice_coef_loss: 0.3975
#
# Epoch 00018: val_loss improved from 0.01123 to 0.01095, saving model to model-brain-mri_bce.h5
# Epoch 19/100
# 99/99 [==============================] - 45s 460ms/step - loss: 0.0130 - accuracy: 0.9951 - dice_coef: 0.6347 - dice_coef_loss: 0.3653 - val_loss: 0.0103 - val_accuracy: 0.9966 - val_dice_coef: 0.6579 - val_dice_coef_loss: 0.3421
#
# Epoch 00019: val_loss improved from 0.01095 to 0.01033, saving model to model-brain-mri_bce.h5
# Epoch 20/100
# 99/99 [==============================] - 47s 471ms/step - loss: 0.0109 - accuracy: 0.9957 - dice_coef: 0.6843 - dice_coef_loss: 0.3157 - val_loss: 0.0120 - val_accuracy: 0.9960 - val_dice_coef: 0.6624 - val_dice_coef_loss: 0.3376
#
# Epoch 00020: val_loss did not improve from 0.01033
# Epoch 21/100
# 99/99 [==============================] - 46s 464ms/step - loss: 0.0108 - accuracy: 0.9957 - dice_coef: 0.6900 - dice_coef_loss: 0.3100 - val_loss: 0.0096 - val_accuracy: 0.9966 - val_dice_coef: 0.6946 - val_dice_coef_loss: 0.3054
#
# Epoch 00021: val_loss improved from 0.01033 to 0.00960, saving model to model-brain-mri_bce.h5
# Epoch 22/100
# 99/99 [==============================] - 46s 463ms/step - loss: 0.0111 - accuracy: 0.9955 - dice_coef: 0.6779 - dice_coef_loss: 0.3221 - val_loss: 0.0107 - val_accuracy: 0.9963 - val_dice_coef: 0.6876 - val_dice_coef_loss: 0.3124
#
# Epoch 00022: val_loss did not improve from 0.00960
# Epoch 23/100
# 99/99 [==============================] - 45s 460ms/step - loss: 0.0100 - accuracy: 0.9958 - dice_coef: 0.7079 - dice_coef_loss: 0.2921 - val_loss: 0.0110 - val_accuracy: 0.9964 - val_dice_coef: 0.6841 - val_dice_coef_loss: 0.3159
#
# Epoch 00023: val_loss did not improve from 0.00960
# Epoch 24/100
# 99/99 [==============================] - 46s 466ms/step - loss: 0.0104 - accuracy: 0.9957 - dice_coef: 0.7026 - dice_coef_loss: 0.2974 - val_loss: 0.0095 - val_accuracy: 0.9967 - val_dice_coef: 0.7192 - val_dice_coef_loss: 0.2808
#
# Epoch 00024: val_loss improved from 0.00960 to 0.00946, saving model to model-brain-mri_bce.h5
# Epoch 25/100
# 99/99 [==============================] - 49s 492ms/step - loss: 0.0102 - accuracy: 0.9957 - dice_coef: 0.7079 - dice_coef_loss: 0.2921 - val_loss: 0.0081 - val_accuracy: 0.9973 - val_dice_coef: 0.7373 - val_dice_coef_loss: 0.2627
#
# Epoch 00025: val_loss improved from 0.00946 to 0.00807, saving model to model-brain-mri_bce.h5
# Epoch 26/100
# 99/99 [==============================] - 48s 482ms/step - loss: 0.0097 - accuracy: 0.9959 - dice_coef: 0.7187 - dice_coef_loss: 0.2813 - val_loss: 0.0090 - val_accuracy: 0.9970 - val_dice_coef: 0.7307 - val_dice_coef_loss: 0.2693
#
# Epoch 00026: val_loss did not improve from 0.00807
# Epoch 27/100
# 99/99 [==============================] - 46s 467ms/step - loss: 0.0089 - accuracy: 0.9961 - dice_coef: 0.7376 - dice_coef_loss: 0.2624 - val_loss: 0.0091 - val_accuracy: 0.9968 - val_dice_coef: 0.7278 - val_dice_coef_loss: 0.2722
#
# Epoch 00027: val_loss did not improve from 0.00807
# Epoch 28/100
# 99/99 [==============================] - 45s 456ms/step - loss: 0.0094 - accuracy: 0.9960 - dice_coef: 0.7347 - dice_coef_loss: 0.2653 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_dice_coef: 0.7715 - val_dice_coef_loss: 0.2285
#
# Epoch 00028: val_loss did not improve from 0.00807
# Epoch 29/100
# 99/99 [==============================] - 47s 473ms/step - loss: 0.0089 - accuracy: 0.9961 - dice_coef: 0.7396 - dice_coef_loss: 0.2604 - val_loss: 0.0080 - val_accuracy: 0.9971 - val_dice_coef: 0.7482 - val_dice_coef_loss: 0.2518
#
# Epoch 00029: val_loss improved from 0.00807 to 0.00804, saving model to model-brain-mri_bce.h5
# Epoch 30/100
# 99/99 [==============================] - 47s 473ms/step - loss: 0.0089 - accuracy: 0.9961 - dice_coef: 0.7376 - dice_coef_loss: 0.2624 - val_loss: 0.0073 - val_accuracy: 0.9974 - val_dice_coef: 0.7883 - val_dice_coef_loss: 0.2117
#
# Epoch 00030: val_loss improved from 0.00804 to 0.00727, saving model to model-brain-mri_bce.h5
# Epoch 31/100
# 99/99 [==============================] - 47s 472ms/step - loss: 0.0087 - accuracy: 0.9961 - dice_coef: 0.7504 - dice_coef_loss: 0.2496 - val_loss: 0.0072 - val_accuracy: 0.9974 - val_dice_coef: 0.7605 - val_dice_coef_loss: 0.2395
#
# Epoch 00031: val_loss improved from 0.00727 to 0.00725, saving model to model-brain-mri_bce.h5
# Epoch 32/100
# 99/99 [==============================] - 46s 470ms/step - loss: 0.0080 - accuracy: 0.9964 - dice_coef: 0.7687 - dice_coef_loss: 0.2313 - val_loss: 0.0066 - val_accuracy: 0.9977 - val_dice_coef: 0.7961 - val_dice_coef_loss: 0.2039
#
# Epoch 00032: val_loss improved from 0.00725 to 0.00656, saving model to model-brain-mri_bce.h5
# Epoch 33/100
# 99/99 [==============================] - 46s 463ms/step - loss: 0.0085 - accuracy: 0.9963 - dice_coef: 0.7630 - dice_coef_loss: 0.2370 - val_loss: 0.0074 - val_accuracy: 0.9975 - val_dice_coef: 0.7683 - val_dice_coef_loss: 0.2317
#
# Epoch 00033: val_loss did not improve from 0.00656
# Epoch 34/100
# 99/99 [==============================] - 46s 460ms/step - loss: 0.0083 - accuracy: 0.9964 - dice_coef: 0.7730 - dice_coef_loss: 0.2270 - val_loss: 0.0079 - val_accuracy: 0.9972 - val_dice_coef: 0.7771 - val_dice_coef_loss: 0.2229
#
# Epoch 00034: val_loss did not improve from 0.00656
# Epoch 35/100
# 99/99 [==============================] - 46s 465ms/step - loss: 0.0076 - accuracy: 0.9965 - dice_coef: 0.7823 - dice_coef_loss: 0.2177 - val_loss: 0.0100 - val_accuracy: 0.9967 - val_dice_coef: 0.7406 - val_dice_coef_loss: 0.2594
#
# Epoch 00035: val_loss did not improve from 0.00656
# Epoch 36/100
# 99/99 [==============================] - 46s 463ms/step - loss: 0.0083 - accuracy: 0.9962 - dice_coef: 0.7657 - dice_coef_loss: 0.2343 - val_loss: 0.0074 - val_accuracy: 0.9973 - val_dice_coef: 0.7755 - val_dice_coef_loss: 0.2245
#
# Epoch 00036: val_loss did not improve from 0.00656
# Epoch 37/100
# 99/99 [==============================] - 46s 466ms/step - loss: 0.0077 - accuracy: 0.9965 - dice_coef: 0.7818 - dice_coef_loss: 0.2182 - val_loss: 0.0077 - val_accuracy: 0.9973 - val_dice_coef: 0.7945 - val_dice_coef_loss: 0.2055
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00037: val_loss did not improve from 0.00656
# Epoch 38/100
# 99/99 [==============================] - 47s 472ms/step - loss: 0.0072 - accuracy: 0.9966 - dice_coef: 0.7931 - dice_coef_loss: 0.2069 - val_loss: 0.0067 - val_accuracy: 0.9975 - val_dice_coef: 0.8136 - val_dice_coef_loss: 0.1864
#
# Epoch 00038: val_loss did not improve from 0.00656
# Epoch 39/100
# 99/99 [==============================] - 45s 457ms/step - loss: 0.0069 - accuracy: 0.9967 - dice_coef: 0.8021 - dice_coef_loss: 0.1979 - val_loss: 0.0071 - val_accuracy: 0.9975 - val_dice_coef: 0.7994 - val_dice_coef_loss: 0.2006
#
# Epoch 00039: val_loss did not improve from 0.00656
# Epoch 40/100
# 99/99 [==============================] - 46s 461ms/step - loss: 0.0071 - accuracy: 0.9967 - dice_coef: 0.7959 - dice_coef_loss: 0.2041 - val_loss: 0.0070 - val_accuracy: 0.9974 - val_dice_coef: 0.8062 - val_dice_coef_loss: 0.1938
#
# Epoch 00040: val_loss did not improve from 0.00656
# Epoch 41/100
# 99/99 [==============================] - 46s 467ms/step - loss: 0.0066 - accuracy: 0.9968 - dice_coef: 0.8066 - dice_coef_loss: 0.1934 - val_loss: 0.0061 - val_accuracy: 0.9978 - val_dice_coef: 0.8096 - val_dice_coef_loss: 0.1904
#
# Epoch 00041: val_loss improved from 0.00656 to 0.00605, saving model to model-brain-mri_bce.h5
# Epoch 42/100
# 99/99 [==============================] - 46s 466ms/step - loss: 0.0072 - accuracy: 0.9967 - dice_coef: 0.8004 - dice_coef_loss: 0.1996 - val_loss: 0.0071 - val_accuracy: 0.9974 - val_dice_coef: 0.7909 - val_dice_coef_loss: 0.2091
#
# Epoch 00042: val_loss did not improve from 0.00605
# Epoch 43/100
# 99/99 [==============================] - 46s 462ms/step - loss: 0.0069 - accuracy: 0.9967 - dice_coef: 0.8023 - dice_coef_loss: 0.1977 - val_loss: 0.0058 - val_accuracy: 0.9979 - val_dice_coef: 0.8016 - val_dice_coef_loss: 0.1984
#
# Epoch 00043: val_loss improved from 0.00605 to 0.00581, saving model to model-brain-mri_bce.h5
# Epoch 44/100
# 99/99 [==============================] - 47s 481ms/step - loss: 0.0070 - accuracy: 0.9967 - dice_coef: 0.8028 - dice_coef_loss: 0.1972 - val_loss: 0.0075 - val_accuracy: 0.9973 - val_dice_coef: 0.8078 - val_dice_coef_loss: 0.1922
#
# Epoch 00044: val_loss did not improve from 0.00581
# Epoch 45/100
# 99/99 [==============================] - 46s 464ms/step - loss: 0.0068 - accuracy: 0.9968 - dice_coef: 0.8052 - dice_coef_loss: 0.1948 - val_loss: 0.0064 - val_accuracy: 0.9976 - val_dice_coef: 0.8131 - val_dice_coef_loss: 0.1869
#
# Epoch 00045: val_loss did not improve from 0.00581
# Epoch 46/100
# 99/99 [==============================] - 46s 470ms/step - loss: 0.0069 - accuracy: 0.9967 - dice_coef: 0.8049 - dice_coef_loss: 0.1951 - val_loss: 0.0067 - val_accuracy: 0.9976 - val_dice_coef: 0.8207 - val_dice_coef_loss: 0.1793
#
# Epoch 00046: val_loss did not improve from 0.00581
# Epoch 47/100
# 99/99 [==============================] - 46s 469ms/step - loss: 0.0067 - accuracy: 0.9968 - dice_coef: 0.8054 - dice_coef_loss: 0.1946 - val_loss: 0.0068 - val_accuracy: 0.9975 - val_dice_coef: 0.7988 - val_dice_coef_loss: 0.2012
#
# Epoch 00047: val_loss did not improve from 0.00581
# Epoch 48/100
# 99/99 [==============================] - 47s 473ms/step - loss: 0.0065 - accuracy: 0.9968 - dice_coef: 0.8065 - dice_coef_loss: 0.1935 - val_loss: 0.0066 - val_accuracy: 0.9976 - val_dice_coef: 0.8209 - val_dice_coef_loss: 0.1791
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00048: val_loss did not improve from 0.00581
# Epoch 49/100
# 99/99 [==============================] - 47s 471ms/step - loss: 0.0068 - accuracy: 0.9968 - dice_coef: 0.8076 - dice_coef_loss: 0.1924 - val_loss: 0.0065 - val_accuracy: 0.9976 - val_dice_coef: 0.8037 - val_dice_coef_loss: 0.1963
#
# Epoch 00049: val_loss did not improve from 0.00581
# Epoch 50/100
# 99/99 [==============================] - 46s 468ms/step - loss: 0.0066 - accuracy: 0.9968 - dice_coef: 0.8115 - dice_coef_loss: 0.1885 - val_loss: 0.0061 - val_accuracy: 0.9978 - val_dice_coef: 0.8158 - val_dice_coef_loss: 0.1842
#
# Epoch 00050: val_loss did not improve from 0.00581
# Epoch 51/100
# 99/99 [==============================] - 47s 474ms/step - loss: 0.0065 - accuracy: 0.9968 - dice_coef: 0.8103 - dice_coef_loss: 0.1897 - val_loss: 0.0065 - val_accuracy: 0.9976 - val_dice_coef: 0.8238 - val_dice_coef_loss: 0.1762
#
# Epoch 00051: val_loss did not improve from 0.00581
# Epoch 52/100
# 99/99 [==============================] - 47s 471ms/step - loss: 0.0070 - accuracy: 0.9968 - dice_coef: 0.8076 - dice_coef_loss: 0.1924 - val_loss: 0.0067 - val_accuracy: 0.9975 - val_dice_coef: 0.8167 - val_dice_coef_loss: 0.1833
#
# Epoch 00052: val_loss did not improve from 0.00581
# Epoch 53/100
# 99/99 [==============================] - 46s 466ms/step - loss: 0.0067 - accuracy: 0.9968 - dice_coef: 0.8027 - dice_coef_loss: 0.1973 - val_loss: 0.0068 - val_accuracy: 0.9975 - val_dice_coef: 0.8019 - val_dice_coef_loss: 0.1981
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00053: val_loss did not improve from 0.00581
# Epoch 00053: early stopping

# %% [markdown]
# ## Plot the Learning Curve

# %%
plt.figure(figsize=(10, 10))
plt.title("Learning curve")
plt.plot(results.history["dice_coef_loss"], label="dice_coef_loss", color="m")
plt.plot(results.history["val_dice_coef_loss"], label="val_dice_coef_loss", color="c")
plt.plot( np.argmin(results.history["dice_coef_loss"]), np.min(results.history["dice_coef_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("dice_loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss", color="m")
plt.plot(results.history["val_loss"], label="val_loss", color="c")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Predictions

# %%
# load the best model
model.load_weights('model-brain-mri_bce.h5')

# %%
eval_results = model.evaluate(valid_gen, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 11/11 [==============================] - 7s 88ms/step - loss: 0.0060 - accuracy: 0.9977 - dice_coef: 0.8164 - dice_coef_loss: 0.1836

# %%
# on test set 

eval_results_test = model.evaluate(test_gen,steps=STEP_SIZE_TEST, verbose=1)
# Out:
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0076 - accuracy: 0.9971 - dice_coef: 0.8306 - dice_coef_loss: 0.1694

# %% [markdown]
# #### Plot some predictions

# %%
for i in range(10):
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    img = cv2.resize(image ,(ImgHeight, ImgWidth))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(mask)
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred))
    plt.title('Prediction')
